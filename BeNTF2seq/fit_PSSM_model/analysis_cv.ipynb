# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('cv_summary.txt', names=['x0','x1','l1r','alpha','learningRate','x3','s1','s2','s3','s4','s5'], delim_whitespace=True)

# %%
df['mean_R_squared'] = (df['s1'] + df['s2'] + df['s3'] + df['s4'] + df['s5'])/5

# %%
df.sort_values(by=['mean_R_squared'], ascending=False)
# Out:
#                                                     x0  x1       l1r  \
# 434  cv_logs/MGM_0.0774263682681127_0.0046415888336...  CV  0.004642
# 425  cv_logs/MGM_0.0774263682681127_0.0027825594022...  CV  0.002783
# 424  cv_logs/MGM_0.0774263682681127_0.0027825594022...  CV  0.002783
# 414  cv_logs/MGM_0.0774263682681127_0.0016681005372...  CV  0.001668
# 435  cv_logs/MGM_0.0774263682681127_0.0046415888336...  CV  0.004642
# 443  cv_logs/MGM_0.0774263682681127_0.0077426368268...  CV  0.007743
# 445  cv_logs/MGM_0.0774263682681127_0.0077426368268...  CV  0.007743
# 433  cv_logs/MGM_0.0774263682681127_0.0046415888336...  CV  0.004642
# 413  cv_logs/MGM_0.0774263682681127_0.0016681005372...  CV  0.001668
# 415  cv_logs/MGM_0.0774263682681127_0.0016681005372...  CV  0.001668
# 444  cv_logs/MGM_0.0774263682681127_0.0077426368268...  CV  0.007743
# 438  cv_logs/MGM_0.0774263682681127_0.0046415888336...  CV  0.004642
# 437  cv_logs/MGM_0.0774263682681127_0.0046415888336...  CV  0.004642
# ...
